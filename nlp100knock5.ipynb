# %%
class Morph:
    """
    1つの形態素を表すクラス
    """

    def __init__(self, surface, base, pos, pos1):
        """
        メンバ変数として表層形（surface），基本形（base），品詞（pos），品詞細分類1（pos1）を持つ.
        """
        self.surface = surface
        self.base = base
        self.pos = pos
        self.pos1 = pos1

    def is_end_of_sentence(self) -> bool: return self.pos1 == '句点'

    def __str__(self) -> str: return 'surface: {}, base: {}, pos: {}, pos1: {}'.format(self.surface, self.base, self.pos, self.pos1)


def make_morph_list(analyzed_file_name: str) -> list:
    """
    係り受け解析済みの文章ファイルを読み込んで、各文をMorphオブジェクトのリストとして表現する
    :param analyzed_file_name 係り受け解析済みの文章ファイル名
    :return list 一つの文章をMorphオブジェクトのリストとして表現したもののリスト
    """
    sentences = []
    sentence = []
    with open(analyzed_file_name, encoding='utf-8') as input_file:
        for line in input_file:
             #* 0 1D 0/1 0.000000
             #吾輩    名詞,代名詞,一般,*,*,*,吾輩,ワガハイ,ワガハイ
             #は      助詞,係助詞,*,*,*,*,は,ハ,ワ
            
            line_list = line.split()
            #['*', '0', '1D', '0/1', '0.000000']
            #['吾輩', '名詞,代名詞,一般,*,*,*,吾輩,ワガハイ,ワガハイ']
            #['は', '助詞,係助詞,*,*,*,*,は,ハ,ワ']
            if (line_list[0] == '*') | (line_list[0] == 'EOS'):
                pass
            else:
                line_list = line_list[0].split(',') + line_list[1].split(',')
                # この時点でline_listはこんな感じ
                # ['始め', '名詞', '副詞可能', '*', '*', '*', '*', '始め', 'ハジメ', 'ハジメ']
                _morph = Morph(surface=line_list[0], base=line_list[7], pos=line_list[1], pos1=line_list[2])
                #printすると__str__通り返ってくるsurface: 一, base: 一, pos: 名詞, pos1: 数
                #格納すると<__main__.Morph object at 0x00000143312DFFC8>, ....
                #何もreturnしてないからね
                sentence.append(_morph)

                if _morph.is_end_of_sentence():
                    #_morphのpos1が句点だったら
                    sentences.append(sentence)
                    sentence = []

    return sentences


morphed_sentences = make_morph_list('neko.txt.cabocha')
#[<__main__.Morph object at 0x0000014330DA8C88>, #文ごと
# 3文目の形態素列を表示
for morph in morphed_sentences[1]:
    print(str(morph))
    #print()とかstr()すると戻る
# Out:
# surface: 名前, base: 名前, pos: 名詞, pos1: 一般
# surface: は, base: は, pos: 助詞, pos1: 係助詞
# surface: まだ, base: まだ, pos: 副詞, pos1: 助詞類接続
# surface: 無い, base: 無い, pos: 形容詞, pos1: 自立
# surface: 。, base: 。, pos: 記号, pos1: 句点

# %%
class Chunk:
    def __init__(self, morphs: list, dst: str, srcs: str) -> None:
        """
        形態素（Morphオブジェクト）のリスト（morphs），係り先文節インデックス番号（dst），係り元文節インデックス番号のリスト（srcs）をメンバ変数に持つ
        """
        self.morphs = morphs
        self.dst = int(dst.strip("D"))
        self.srcs = int(srcs)

    # 以下は後々使うメソッドです.
    def join_morphs(self) -> str:
        return ''.join([_morph.surface for _morph in self.morphs if _morph.pos != '記号'])
        #句点とかの記号以外を出力
        #surface: 。, base: 。, pos: 記号, pos1: 句点
        #_morph自体はオブジェクトだけど_morph.pos,_morph.surfaceは普通に出てくる
    def has_noun(self) -> bool:
        return any([_morph.pos == '名詞' for _morph in self.morphs])

    def has_verb(self) -> bool:
        return any([_morph.pos == '動詞' for _morph in self.morphs])

    def has_particle(self) -> bool:
        return any([_morph.pos == '助詞' for _morph in self.morphs])

    def has_sahen_connection_noun_plus_wo(self) -> bool:
        """
        「サ変接続名詞+を（助詞）」を含むかどうかを返す.
        """
        for idx, _morph in enumerate(self.morphs):
            if _morph.pos == '名詞' and _morph.pos1 == 'サ変接続' and len(self.morphs[idx:]) > 1 and \
                            self.morphs[idx + 1].pos == '助詞' and self.morphs[idx + 1].base == 'を':
                return True

        return False

    def first_verb(self) -> Morph:
        return [_morph for _morph in self.morphs if _morph.pos == '動詞'][0]

    def last_particle(self) -> list:
        return [_morph for _morph in self.morphs if _morph.pos == '助詞'][-1]

    def pair(self, sentence: list) -> str:
        return self.join_morphs() + '\t' + sentence[self.dst].join_morphs()

    def replace_noun(self, alt: str) -> None:
        """
        名詞の表象を置換する.
        """
        for _morph in self.morphs:
            if _morph.pos == '名詞':
                _morph.surface = alt

    def __str__(self) -> str:
        return 'srcs: {}, dst: {}, morphs: ({})'.format(self.srcs, self.dst, ' / '.join([str(_morph) for _morph in self.morphs]))


def make_chunk_list(analyzed_file_name: str) -> list:
    """
    係り受け解析済みの文章ファイルを読み込んで、各文をChunkオブジェクトのリストとして表現する
    :param analyzed_file_name 係り受け解析済みの文章ファイル名
    :return list 一つの文章をChunkオブジェクトのリストとして表現したもののリスト
    """
    sentences = []
    sentence = []
    _chunk = None
    count=0
    with open(analyzed_file_name, encoding='utf-8') as input_file:
        for line in input_file:
            #
            #count+=1
            #if count==20:
            #    break
            #
            line_list = line.split()
            #print('手始め',line_list)
            if line_list[0] == '*':#文頭
            #    print('上は文頭')
                if _chunk is not None:
            #        print('元からあった_chunk',_chunk)
                    sentence.append(_chunk)#元々あったやつ
            #        print('_chunk入れた',sentence)
                _chunk = Chunk(morphs=[], dst=line_list[2], srcs=line_list[1])
            #    print('文頭の','chunkを定義しなおした',_chunk)
                #文頭のline_list
                #['*', '0', '-1D', '0/0', '0.000000']
            elif line_list[0] == 'EOS':  # End of sentence
            #    print('上はケツ')
                if _chunk is not None:
            #        print('元からあった_chunk',_chunk)
                    sentence.append(_chunk)
            #        print('_chunk入れた',sentence)
                if len(sentence) > 0:
            #        print('sentence',sentence)
                    sentences.append(sentence)
                #リセット
                _chunk = None
                sentence = []
            else:#文頭でもケツでもない
            #    print('上は文頭でもケツでもない')
            #    print('元のlist',line_list)
                line_list = line_list[0].split(',') + line_list[1].split(',')
            #    print('listを定義しなおした',line_list)
                # この時点でline_listはこんな感じ
                # ['始め', '名詞', '副詞可能', '*', '*', '*', '*', '始め', 'ハジメ', 'ハジメ']
                _morph = Morph(surface=line_list[0], base=line_list[7], pos=line_list[1], pos1=line_list[2])
            #    print('_morph',_morph)
                _chunk.morphs.append(_morph)
            #    print('morphに_chunkを足したよ',_chunk)

    return sentences


chunked_sentences = make_chunk_list('neko.txt.cabocha')
print(len(chunked_sentences))
# 3文目の形態素列を表示
for chunk in chunked_sentences[2]:
    
    print(str(chunk))
# Out:
# 9210
# srcs: 0, dst: 2, morphs: (surface: 名前, base: 名前, pos: 名詞, pos1: 一般 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# srcs: 1, dst: 2, morphs: (surface: まだ, base: まだ, pos: 副詞, pos1: 助詞類接続)
# srcs: 2, dst: -1, morphs: (surface: 無い, base: 無い, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)

# %%
def is_valid_chunk(_chunk, sentence):
    return _chunk.join_morphs() != '' and _chunk.dst > -1 and sentence[_chunk.dst].join_morphs() != ''
#_chunk.join_morphs() != '':記号以外

paired_sentences = [[chunk.pair(sentence) for chunk in sentence if is_valid_chunk(chunk, sentence)] for sentence in chunked_sentences if len(sentence) > 1]
print(paired_sentences[0:100])
#chumked_sentence:[<__main__.Chunk object at 0x000001AB02B61888>]
#srcs: 0, dst: 2, morphs: (surface: 呼ん, base: 呼ぶ, pos: 動詞, pos1: 自立 / surface: で, base: で, pos: 助詞, pos1: 接続助詞)
# Out:
# [['吾輩は\t猫である'], ['名前は\t無い', 'まだ\t無い'], ['どこで\t生れたか', '生れたか\tつかぬ', 'とんと\tつかぬ', '見当が\tつかぬ'], ['何でも\t薄暗い', '薄暗い\t所で', 'じめじめした\t所で', '所で\t泣いて', 'ニャーニャー\t泣いて', '泣いて\t記憶している', 'いた事だけは\t記憶している'], ['吾輩は\t見た', 'ここで\t始めて', '始めて\t人間という', '人間という\tものを', 'ものを\t見た'], ['しかも\t種族であったそうだ', 'あとで\t聞くと', '聞くと\t種族であったそうだ', 'それは\t種族であったそうだ', '書生という\t人間中で', '人間中で\t種族であったそうだ', '一番\t獰悪な', '獰悪な\t種族であったそうだ'], ['この\t書生というのは', '書生というのは\t話である', '時々\t捕えて', '我々を\t捕えて', '捕えて\t煮て', '煮て\t食うという', '食うという\t話である'], ['しかし\t思わなかった', 'その\t当時は', '当時は\tなかったから', '何という\t考も', '考も\tなかったから', 'なかったから\t思わなかった', '別段\t恐し', '恐し\t思わなかった', 'いとも\t思わなかった'], ['ただ\t載せられて', '彼の\t掌に', '掌に\t載せられて', '載せられて\t持ち上げられた', 'スーと\t持ち上げられた', '持ち上げられた\t時', '時\tフワフワした', '何だか\tフワフワした', 'フワフワした\t感じが', '感じが\tあったばかりである'], ['掌の\t上で', '上で\t落ちついて', '少し\t落ちついて', '落ちついて\t見たのが', '書生の\t顔を', '顔を\t見たのが', '見たのが\t人間という', 'いわゆる\t人間という', '人間という\tものの', 'ものの\t見始であろう'], ['この\t時', '時\tものだと', '妙な\tものだと', 'ものだと\t思った', '思った\t感じが', '感じが\t残っている', '今でも\t残っている'], ['第一毛をもって\t装飾されべきはずの', '装飾されべきはずの\t顔が', '顔が\tつるつるして', 'つるつるして\t薬缶だ', 'まるで\t薬缶だ'], ['その後\t逢ったが', '猫にも\t逢ったが', 'だいぶ\t逢ったが', '逢ったが\tない', 'こんな\t片輪には', '片輪には\tない', '一度も\t出会わした', '出会わした\t事が', '事が\tない'], ['のみならず\t突起している', '顔の\t真中が', '真中が\t突起している', 'あまりに\t突起している'], ['そうして\t吹く', 'その穴の\t中から', '中から\t吹く', '時々\t吹く', 'ぷうぷうと煙を\t吹く'], ['どうも\t咽せぽくて', '咽せぽくて\t弱った', '実に\t弱った'], ['これが\tものである', '人間の\t飲む', '飲む\t煙草という', '煙草という\tものである', 'ものである\t事は', '事は\t知った', 'ようやく\t知った', 'この\t頃', '頃\t知った'], ['この\t書生の', '書生の\t掌の', '掌の\t裏で', '裏で\t坐って', 'しばらくは\tよい', 'よい\t心持に', '心持に\t坐って', '坐って\tおったが', 'おったが\t運転し始めた', 'しばらく\tすると', 'すると\t運転し始めた', '非常な\t速力で', '速力で\t運転し始めた'], ['書生が\t動くのか', '動くのか\t動くのか', '自分だけが\t動くのか', '動くのか\t分らないが', '分らないが\t廻る', '無暗に\t廻る', '眼が\t廻る'], ['胸が\t悪くなる'], ['到底\t助からないと', '助からないと\t思っていると', '思っていると\t出た', 'どさりと\tして', '音が\tして', 'して\t出た', '眼から\t出た', '火が\t出た'], ['それまでは\t記憶しているが', '記憶しているが\t分らない', 'あとは\t分らない', '何の\t事やら', '事やら\t分らない', 'いくら\t考え出そうとしても', '考え出そうとしても\t分らない'], ['ふと\t付いて', '気が\t付いて', '付いて\t見ると', '見ると\tいない', '書生は\tいない'], ['たくさん\tおった', 'おった\t兄弟が', '兄弟が\t見えぬ', '一疋も\t見えぬ'], ['肝心の\t母親さえ', '母親さえ\t隠してしまった', '姿を\t隠してしまった'], ['その\t上今までの', '上今までの\t所とは', '所とは\t違って', '違って\t明るい', '無暗に\t明るい'], ['眼を\t明いていられぬくらいだ'], ['はてな\t痛い', '何でも\tおかしいと', '容子が\tおかしいと', 'おかしいと\t痛い', 'のそのそ\t這い出して', '這い出して\t見ると', '見ると\t痛い', '非常に\t痛い'], ['吾輩は\t棄てられたのである', '藁の\t上から', '上から\t棄てられたのである', '急に\t棄てられたのである', '笹原の\t中へ', '中へ\t棄てられたのである'], ['ようやくの\t思いで', '思いで\t這い出すと', '笹原を\t這い出すと', '這い出すと\tある', '向うに\tある', '大きな\t池が', '池が\tある'], ['吾輩は\t見た', '池の\t前に', '前に\t坐って', '坐って\tしたら', 'どう\tしたら', 'したら\tよかろうと', 'よかろうと\t考えて', '考えて\t見た'], ['別に\t出ない', 'これという\t分別も', '分別も\t出ない'], ['しばらく\tして', 'して\t泣いたら', '泣いたら\t来てくれるかと', '書生がまた\t来てくれるかと', '迎に\t来てくれるかと', '来てくれるかと\t考え付いた'], ['ニャー\tニャーと', 'ニャーと\t試みに', '試みに\tやって', 'やって\t見たが', '見たが\t来ない', '誰も\t来ない'], ['そのうち\t渡って', '池の\t上を', '上を\t渡って', 'さらさらと\t渡って', '風が\t渡って', '渡って\tかかる', '日が\tかかる', '暮れ\tかかる'], ['腹が\t減って来た', '非常に\t減って来た'], ['泣きたくても\t出ない', '声が\t出ない'], ['仕方が\tない', 'ない\t廻り始めた', '何でも\t廻り始めた', 'よいから\t所まで', '食物の\tある', 'ある\t所まで', '所まで\tある', 'ある\t廻り始めた', 'こうと\tして', '決心を\tして', 'して\tそろり', 'そろり\t廻り始めた', 'そろりと\t廻り始めた', '池を\t廻り始めた', '左りに\t廻り始めた'], ['どうも\t苦しい', '非常に\t苦しい'], ['そこを\t我慢して', '我慢して\t這って行くと', '無理やりに\t這って行くと', '這って行くと\t出た', 'ようやくの\t事で', '事で\t出た', '何となく\t人間臭い', '人間臭い\t所へ', '所へ\t出た'], ['ここへ\t這入ったら', '這入ったら\tなると', 'どうにか\tなると', 'なると\t思って', '思って\tもぐり込んだ', '竹垣の\t崩れた', '崩れた\t穴から', '穴から\tもぐり込んだ', 'とある\t邸内に', '邸内に\tもぐり込んだ'], ['縁は\tもので', '不思議な\tもので', 'もので\t餓死したかも知れんのである', 'もし\t破れていなかったなら', 'この\t竹垣が', '竹垣が\t破れていなかったなら', '破れていなかったなら\t餓死したかも知れんのである', '吾輩は\t餓死したかも知れんのである', 'ついに\t餓死したかも知れんのである', '路傍に\t餓死したかも知れんのである'], ['一樹の\t蔭とは', '蔭とは\t云った', 'よく\t云った', '云った\tものだ'], ['この\t垣根の', '垣根の\t穴は', '穴は\tなっている', '今日に\t至るまで', '至るまで\t訪問する', '吾輩が\t訪問する', '隣家の\t三毛を', '三毛を\t訪問する', '訪問する\t時の', '時の\t通路に', '通路に\tなっている'], ['さて\t分らない', '邸へは\t忍び込んだものの', '忍び込んだものの\t分らない', 'これから\t善いか', '先\t善いか', 'どうして\t善いか', '善いか\t分らない'], ['その\tうちに', 'うちに\t暗くなる', '暗くなる\t減る', '腹は\t減る', '減る\t寒し', '寒さは\t寒し', '寒し\t降って来るという', '雨が\t降って来るという', '降って来るという\t始末で', '始末で\t出来なくなった' ...

# %%
for sentence in chunked_sentences[:50:]:
    for _chunk in sentence[:10:]:
        print(_chunk.morphs)
        print(_chunk.dst)
        print(sentence[_chunk.dst])
        #print(_chunk.join_morphs())
# Out:
# [<__main__.Morph object at 0x000001AB10123E48>]
# -1
# srcs: 0, dst: -1, morphs: (surface: 一, base: 一, pos: 名詞, pos1: 数)
# [<__main__.Morph object at 0x000001AB100F9708>, <__main__.Morph object at 0x000001AB100F9748>]
# 1
# srcs: 1, dst: -1, morphs: (surface: 猫, base: 猫, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F9788>, <__main__.Morph object at 0x000001AB100F97C8>, <__main__.Morph object at 0x000001AB100F9808>, <__main__.Morph object at 0x000001AB100F9888>]
# -1
# srcs: 1, dst: -1, morphs: (surface: 猫, base: 猫, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F98C8>, <__main__.Morph object at 0x000001AB100F9948>]
# 2
# srcs: 2, dst: -1, morphs: (surface: 無い, base: 無い, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F9988>]
# 2
# srcs: 2, dst: -1, morphs: (surface: 無い, base: 無い, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F99C8>, <__main__.Morph object at 0x000001AB100F9A08>]
# -1
# srcs: 2, dst: -1, morphs: (surface: 無い, base: 無い, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F9B48>, <__main__.Morph object at 0x000001AB100F9B08>]
# 1
# srcs: 1, dst: 4, morphs: (surface: 生れ, base: 生れる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: か, base: か, pos: 助詞, pos1: 副助詞／並立助詞／終助詞)
# [<__main__.Morph object at 0x000001AB100F9B88>, <__main__.Morph object at 0x000001AB100F9BC8>, <__main__.Morph object at 0x000001AB100F9C08>]
# 4
# srcs: 4, dst: -1, morphs: (surface: つか, base: つく, pos: 動詞, pos1: 自立 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F9C88>]
# 4
# srcs: 4, dst: -1, morphs: (surface: つか, base: つく, pos: 動詞, pos1: 自立 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F9CC8>, <__main__.Morph object at 0x000001AB100F9D08>]
# 4
# srcs: 4, dst: -1, morphs: (surface: つか, base: つく, pos: 動詞, pos1: 自立 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F9D88>, <__main__.Morph object at 0x000001AB100F9E08>, <__main__.Morph object at 0x000001AB100F9E48>]
# -1
# srcs: 4, dst: -1, morphs: (surface: つか, base: つく, pos: 動詞, pos1: 自立 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB100F9EC8>, <__main__.Morph object at 0x000001AB100F9F88>]
# 1
# srcs: 1, dst: 3, morphs: (surface: 薄暗い, base: 薄暗い, pos: 形容詞, pos1: 自立)
# [<__main__.Morph object at 0x000001AB100F9FC8>]
# 3
# srcs: 3, dst: 5, morphs: (surface: 所, base: 所, pos: 名詞, pos1: 非自立 / surface: で, base: で, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10105048>, <__main__.Morph object at 0x000001AB10105088>, <__main__.Morph object at 0x000001AB10105108>]
# 3
# srcs: 3, dst: 5, morphs: (surface: 所, base: 所, pos: 名詞, pos1: 非自立 / surface: で, base: で, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10105188>, <__main__.Morph object at 0x000001AB101051C8>]
# 5
# srcs: 5, dst: 7, morphs: (surface: 泣い, base: 泣く, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10105288>]
# 5
# srcs: 5, dst: 7, morphs: (surface: 泣い, base: 泣く, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB101052C8>, <__main__.Morph object at 0x000001AB10105348>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 記憶, base: 記憶, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105388>, <__main__.Morph object at 0x000001AB10105408>, <__main__.Morph object at 0x000001AB10105448>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 記憶, base: 記憶, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101054C8>, <__main__.Morph object at 0x000001AB10105508>, <__main__.Morph object at 0x000001AB10105548>, <__main__.Morph object at 0x000001AB101055C8>, <__main__.Morph object at 0x000001AB10105608>]
# -1
# srcs: 7, dst: -1, morphs: (surface: 記憶, base: 記憶, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105688>, <__main__.Morph object at 0x000001AB10105748>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 見, base: 見る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105788>, <__main__.Morph object at 0x000001AB101057C8>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 始め, base: 始める, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10105808>, <__main__.Morph object at 0x000001AB10105888>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 人間, base: 人間, pos: 名詞, pos1: 一般 / surface: という, base: という, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB101058C8>, <__main__.Morph object at 0x000001AB10105948>]
# 4
# srcs: 4, dst: 5, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: を, base: を, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10105988>, <__main__.Morph object at 0x000001AB10105A08>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 見, base: 見る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105A48>, <__main__.Morph object at 0x000001AB10105AC8>, <__main__.Morph object at 0x000001AB10105B08>]
# -1
# srcs: 5, dst: -1, morphs: (surface: 見, base: 見る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105BC8>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 種族, base: 種族, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: あっ, base: ある, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: そう, base: そう, pos: 名詞, pos1: 特殊 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105C48>, <__main__.Morph object at 0x000001AB10105C88>]
# 2
# srcs: 2, dst: 8, morphs: (surface: 聞く, base: 聞く, pos: 動詞, pos1: 自立 / surface: と, base: と, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10105CC8>, <__main__.Morph object at 0x000001AB10105D48>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 種族, base: 種族, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: あっ, base: ある, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: そう, base: そう, pos: 名詞, pos1: 特殊 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105D88>, <__main__.Morph object at 0x000001AB10105E08>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 種族, base: 種族, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: あっ, base: ある, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: そう, base: そう, pos: 名詞, pos1: 特殊 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10105E48>, <__main__.Morph object at 0x000001AB10105EC8>]
# 5
# srcs: 5, dst: 8, morphs: (surface: 人間, base: 人間, pos: 名詞, pos1: 一般 / surface: 中, base: 中, pos: 名詞, pos1: 接尾 / surface: で, base: で, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10105F08>, <__main__.Morph object at 0x000001AB10105F88>, <__main__.Morph object at 0x000001AB10105FC8>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 種族, base: 種族, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: あっ, base: ある, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: そう, base: そう, pos: 名詞, pos1: 特殊 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1013C0C8>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 獰悪, base: 獰悪, pos: 名詞, pos1: 形容動詞語幹 / surface: な, base: だ, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB1013C108>, <__main__.Morph object at 0x000001AB1013C148>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 種族, base: 種族, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: あっ, base: ある, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: そう, base: そう, pos: 名詞, pos1: 特殊 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1013C248>, <__main__.Morph object at 0x000001AB1013C288>, <__main__.Morph object at 0x000001AB1013C308>, <__main__.Morph object at 0x000001AB1013C348>, <__main__.Morph object at 0x000001AB1013C388>, <__main__.Morph object at 0x000001AB1013C408>, <__main__.Morph object at 0x000001AB1013C448>]
# -1
# srcs: 8, dst: -1, morphs: (surface: 種族, base: 種族, pos: 名詞, pos1: 一般 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: あっ, base: ある, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: そう, base: そう, pos: 名詞, pos1: 特殊 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1013C508>]
# 1
# srcs: 1, dst: 7, morphs: (surface: 書生, base: 書生, pos: 名詞, pos1: 一般 / surface: という, base: という, pos: 助詞, pos1: 格助詞 / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB1013C588>, <__main__.Morph object at 0x000001AB1013C5C8>, <__main__.Morph object at 0x000001AB1013C648>, <__main__.Morph object at 0x000001AB1013C688>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 話, base: 話, pos: 名詞, pos1: サ変接続 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1013C708>]
# 4
# srcs: 4, dst: 5, morphs: (surface: 捕え, base: 捕える, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1013C7C8>, <__main__.Morph object at 0x000001AB1013C808>]
# 4
# srcs: 4, dst: 5, morphs: (surface: 捕え, base: 捕える, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1013C8C8>, <__main__.Morph object at 0x000001AB1013C908>]
# 5
# srcs: 5, dst: 6, morphs: (surface: 煮, base: 煮る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1013C9C8>, <__main__.Morph object at 0x000001AB1013CA08>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 食う, base: 食う, pos: 動詞, pos1: 自立 / surface: という, base: という, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1013CB08>, <__main__.Morph object at 0x000001AB1013CB48>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 話, base: 話, pos: 名詞, pos1: サ変接続 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1013CC08>, <__main__.Morph object at 0x000001AB1013CC48>, <__main__.Morph object at 0x000001AB1013CCC8>, <__main__.Morph object at 0x000001AB1013CD08>]
# -1
# srcs: 7, dst: -1, morphs: (surface: 話, base: 話, pos: 名詞, pos1: サ変接続 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1013CE08>]
# 9
# srcs: 9, dst: -1, morphs: (surface: 思わ, base: 思う, pos: 動詞, pos1: 自立 / surface: なかっ, base: ない, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1013CE88>]
# 2
# srcs: 2, dst: 5, morphs: (surface: 当時, base: 当時, pos: 名詞, pos1: 副詞可能 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB1013CF48>, <__main__.Morph object at 0x000001AB1013CF88>]
# 5
# srcs: 5, dst: 9, morphs: (surface: なかっ, base: ない, pos: 形容詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: から, base: から, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10122088>, <__main__.Morph object at 0x000001AB101220C8>]
# 4
# srcs: 4, dst: 5, morphs: (surface: 考, base: 考, pos: 名詞, pos1: 一般 / surface: も, base: も, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB10122188>, <__main__.Morph object at 0x000001AB101221C8>]
# 5
# srcs: 5, dst: 9, morphs: (surface: なかっ, base: ない, pos: 形容詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: から, base: から, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10122288>, <__main__.Morph object at 0x000001AB101222C8>, <__main__.Morph object at 0x000001AB10122388>]
# 9
# srcs: 9, dst: -1, morphs: (surface: 思わ, base: 思う, pos: 動詞, pos1: 自立 / surface: なかっ, base: ない, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10122408>]
# 7
# srcs: 7, dst: 9, morphs: (surface: 恐し, base: 恐い, pos: 形容詞, pos1: 自立)
# [<__main__.Morph object at 0x000001AB101224C8>]
# 9
# srcs: 9, dst: -1, morphs: (surface: 思わ, base: 思う, pos: 動詞, pos1: 自立 / surface: なかっ, base: ない, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10122588>]
# 9
# srcs: 9, dst: -1, morphs: (surface: 思わ, base: 思う, pos: 動詞, pos1: 自立 / surface: なかっ, base: ない, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10122648>, <__main__.Morph object at 0x000001AB10122688>, <__main__.Morph object at 0x000001AB101226C8>, <__main__.Morph object at 0x000001AB10122708>]
# -1
# srcs: 9, dst: -1, morphs: (surface: 思わ, base: 思う, pos: 動詞, pos1: 自立 / surface: なかっ, base: ない, pos: 助動詞, pos1: * / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101227C8>]
# 3
# srcs: 3, dst: 5, morphs: (surface: 載せ, base: 載せる, pos: 動詞, pos1: 自立 / surface: られ, base: られる, pos: 動詞, pos1: 接尾 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10122848>, <__main__.Morph object at 0x000001AB10122888>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 掌, base: 掌, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10122948>, <__main__.Morph object at 0x000001AB10122988>]
# 3
# srcs: 3, dst: 5, morphs: (surface: 載せ, base: 載せる, pos: 動詞, pos1: 自立 / surface: られ, base: られる, pos: 動詞, pos1: 接尾 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10122A48>, <__main__.Morph object at 0x000001AB10122A88>, <__main__.Morph object at 0x000001AB10122B08>]
# 5
# srcs: 5, dst: 6, morphs: (surface: 持ち上げ, base: 持ち上げる, pos: 動詞, pos1: 自立 / surface: られ, base: られる, pos: 動詞, pos1: 接尾 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10122B88>, <__main__.Morph object at 0x000001AB10122BC8>]
# 5
# srcs: 5, dst: 6, morphs: (surface: 持ち上げ, base: 持ち上げる, pos: 動詞, pos1: 自立 / surface: られ, base: られる, pos: 動詞, pos1: 接尾 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10122C88>, <__main__.Morph object at 0x000001AB10122CC8>, <__main__.Morph object at 0x000001AB10122D88>]
# 6
# srcs: 6, dst: 8, morphs: (surface: 時, base: 時, pos: 名詞, pos1: 非自立)
# [<__main__.Morph object at 0x000001AB10122E08>]
# 8
# srcs: 8, dst: 9, morphs: (surface: フワフワ, base: フワフワ, pos: 副詞, pos1: 助詞類接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10122EC8>]
# 8
# srcs: 8, dst: 9, morphs: (surface: フワフワ, base: フワフワ, pos: 副詞, pos1: 助詞類接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10122F88>, <__main__.Morph object at 0x000001AB10122FC8>, <__main__.Morph object at 0x000001AB1011B088>]
# 9
# srcs: 9, dst: 10, morphs: (surface: 感じ, base: 感じ, pos: 名詞, pos1: 一般 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011B108>, <__main__.Morph object at 0x000001AB1011B148>]
# 10
# srcs: 10, dst: -1, morphs: (surface: あっ, base: ある, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: ばかり, base: ばかり, pos: 助詞, pos1: 副助詞 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1011B488>, <__main__.Morph object at 0x000001AB1011B4C8>]
# 1
# srcs: 1, dst: 3, morphs: (surface: 上, base: 上, pos: 名詞, pos1: 非自立 / surface: で, base: で, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011B548>, <__main__.Morph object at 0x000001AB1011B588>]
# 3
# srcs: 3, dst: 6, morphs: (surface: 落ちつい, base: 落ちつく, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1011B648>]
# 3
# srcs: 3, dst: 6, morphs: (surface: 落ちつい, base: 落ちつく, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1011B708>, <__main__.Morph object at 0x000001AB1011B748>]
# 6
# srcs: 6, dst: 8, morphs: (surface: 見, base: 見る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011B808>, <__main__.Morph object at 0x000001AB1011B848>]
# 5
# srcs: 5, dst: 6, morphs: (surface: 顔, base: 顔, pos: 名詞, pos1: 一般 / surface: を, base: を, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011B908>, <__main__.Morph object at 0x000001AB1011B948>]
# 6
# srcs: 6, dst: 8, morphs: (surface: 見, base: 見る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011BA48>, <__main__.Morph object at 0x000001AB1011BA88>, <__main__.Morph object at 0x000001AB1011BB08>, <__main__.Morph object at 0x000001AB1011BB48>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 人間, base: 人間, pos: 名詞, pos1: 一般 / surface: という, base: という, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011BBC8>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 人間, base: 人間, pos: 名詞, pos1: 一般 / surface: という, base: という, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011BC88>, <__main__.Morph object at 0x000001AB1011BCC8>]
# 9
# srcs: 9, dst: 10, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: の, base: の, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1011BD88>, <__main__.Morph object at 0x000001AB1011BDC8>]
# 10
# srcs: 10, dst: -1, morphs: (surface: 見, base: 見る, pos: 動詞, pos1: 自立 / surface: 始, base: 始, pos: 名詞, pos1: 固有名詞 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: あろ, base: ある, pos: 助動詞, pos1: * / surface: う, base: う, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10125148>]
# 1
# srcs: 1, dst: 3, morphs: (surface: 時, base: 時, pos: 名詞, pos1: 非自立)
# [<__main__.Morph object at 0x000001AB101251C8>]
# 3
# srcs: 3, dst: 4, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: と, base: と, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10125288>, <__main__.Morph object at 0x000001AB101252C8>]
# 3
# srcs: 3, dst: 4, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: と, base: と, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10125388>, <__main__.Morph object at 0x000001AB101253C8>, <__main__.Morph object at 0x000001AB10125448>]
# 4
# srcs: 4, dst: 5, morphs: (surface: 思っ, base: 思う, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB101254C8>, <__main__.Morph object at 0x000001AB10125508>]
# 5
# srcs: 5, dst: 7, morphs: (surface: 感じ, base: 感じ, pos: 名詞, pos1: 一般 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB101255C8>, <__main__.Morph object at 0x000001AB10125608>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 残っ, base: 残る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10125708>, <__main__.Morph object at 0x000001AB10125748>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 残っ, base: 残る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10125808>, <__main__.Morph object at 0x000001AB10125848>, <__main__.Morph object at 0x000001AB101258C8>, <__main__.Morph object at 0x000001AB10125908>]
# -1
# srcs: 7, dst: -1, morphs: (surface: 残っ, base: 残る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10125A08>, <__main__.Morph object at 0x000001AB10125A48>, <__main__.Morph object at 0x000001AB10125A88>, <__main__.Morph object at 0x000001AB10125AC8>]
# 1
# srcs: 1, dst: 2, morphs: (surface: 装飾, base: 装飾, pos: 名詞, pos1: サ変接続 / surface: さ, base: する, pos: 動詞, pos1: 自立 / surface: れ, base: れる, pos: 動詞, pos1: 接尾 / surface: べき, base: べし, pos: 助動詞, pos1: * / surface: はず, base: はず, pos: 名詞, pos1: 非自立 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# [<__main__.Morph object at 0x000001AB10125B48>, <__main__.Morph object at 0x000001AB10125B88>, <__main__.Morph object at 0x000001AB10125C08>, <__main__.Morph object at 0x000001AB10125C48>, <__main__.Morph object at 0x000001AB10125C88>, <__main__.Morph object at 0x000001AB10125D08>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 顔, base: 顔, pos: 名詞, pos1: 一般 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10125D88>, <__main__.Morph object at 0x000001AB10125DC8>]
# 3
# srcs: 3, dst: 5, morphs: (surface: つるつる, base: つるつる, pos: 副詞, pos1: 一般 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10125E88>, <__main__.Morph object at 0x000001AB10125EC8>, <__main__.Morph object at 0x000001AB10125F48>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 薬缶, base: 薬缶, pos: 名詞, pos1: 一般 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10125FC8>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 薬缶, base: 薬缶, pos: 名詞, pos1: 一般 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012A0C8>, <__main__.Morph object at 0x000001AB1012A108>, <__main__.Morph object at 0x000001AB1012A1C8>]
# -1
# srcs: 5, dst: -1, morphs: (surface: 薬缶, base: 薬缶, pos: 名詞, pos1: 一般 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012A2C8>]
# 3
# srcs: 3, dst: 9, morphs: (surface: 逢っ, base: 逢う, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: が, base: が, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1012A348>, <__main__.Morph object at 0x000001AB1012A388>, <__main__.Morph object at 0x000001AB1012A408>]
# 3
# srcs: 3, dst: 9, morphs: (surface: 逢っ, base: 逢う, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: が, base: が, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1012A488>]
# 3
# srcs: 3, dst: 9, morphs: (surface: 逢っ, base: 逢う, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: が, base: が, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1012A548>, <__main__.Morph object at 0x000001AB1012A588>, <__main__.Morph object at 0x000001AB1012A608>]
# 9
# srcs: 9, dst: -1, morphs: (surface: ない, base: ない, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012A688>]
# 5
# srcs: 5, dst: 9, morphs: (surface: 片, base: 片, pos: 接頭詞, pos1: 名詞接続 / surface: 輪, base: 輪, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB1012A748>, <__main__.Morph object at 0x000001AB1012A788>, <__main__.Morph object at 0x000001AB1012A848>, <__main__.Morph object at 0x000001AB1012A888>]
# 9
# srcs: 9, dst: -1, morphs: (surface: ない, base: ない, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012A908>, <__main__.Morph object at 0x000001AB1012A948>, <__main__.Morph object at 0x000001AB1012A9C8>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 出会わ, base: 出会う, pos: 動詞, pos1: 自立 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB1012AA48>, <__main__.Morph object at 0x000001AB1012AA88>, <__main__.Morph object at 0x000001AB1012AB08>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 事, base: 事, pos: 名詞, pos1: 非自立 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1012AB88>, <__main__.Morph object at 0x000001AB1012ABC8>]
# 9
# srcs: 9, dst: -1, morphs: (surface: ない, base: ない, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012AC88>, <__main__.Morph object at 0x000001AB1012ACC8>]
# -1
# srcs: 9, dst: -1, morphs: (surface: ない, base: ない, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012ADC8>, <__main__.Morph object at 0x000001AB1012AE08>, <__main__.Morph object at 0x000001AB1012AE48>]
# 4
# srcs: 4, dst: -1, morphs: (surface: 突起, base: 突起, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012AEC8>, <__main__.Morph object at 0x000001AB1012AF08>]
# 2
# srcs: 2, dst: 4, morphs: (surface: 真中, base: 真中, pos: 名詞, pos1: 一般 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1012AFC8>, <__main__.Morph object at 0x000001AB1012F048>]
# 4
# srcs: 4, dst: -1, morphs: (surface: 突起, base: 突起, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012F108>]
# 4
# srcs: 4, dst: -1, morphs: (surface: 突起, base: 突起, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012F1C8>, <__main__.Morph object at 0x000001AB1012F208>, <__main__.Morph object at 0x000001AB1012F288>, <__main__.Morph object at 0x000001AB1012F2C8>, <__main__.Morph object at 0x000001AB1012F308>]
# -1
# srcs: 4, dst: -1, morphs: (surface: 突起, base: 突起, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012F488>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 吹く, base: 吹く, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012F508>, <__main__.Morph object at 0x000001AB1012F548>, <__main__.Morph object at 0x000001AB1012F5C8>]
# 2
# srcs: 2, dst: 5, morphs: (surface: 中, base: 中, pos: 名詞, pos1: 非自立 / surface: から, base: から, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1012F648>, <__main__.Morph object at 0x000001AB1012F688>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 吹く, base: 吹く, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012F748>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 吹く, base: 吹く, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012F848>, <__main__.Morph object at 0x000001AB1012F808>, <__main__.Morph object at 0x000001AB1012F8C8>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 吹く, base: 吹く, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012F948>, <__main__.Morph object at 0x000001AB1012F988>]
# -1
# srcs: 5, dst: -1, morphs: (surface: 吹く, base: 吹く, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012FB08>]
# 1
# srcs: 1, dst: 3, morphs: (surface: 咽, base: 咽, pos: 名詞, pos1: 一般 / surface: せ, base: する, pos: 動詞, pos1: 自立 / surface: ぽく, base: ぽい, pos: 形容詞, pos1: 接尾 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1012FB88>, <__main__.Morph object at 0x000001AB1012FBC8>, <__main__.Morph object at 0x000001AB1012FC48>, <__main__.Morph object at 0x000001AB1012FC88>]
# 3
# srcs: 3, dst: -1, morphs: (surface: 弱っ, base: 弱る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012FD08>]
# 3
# srcs: 3, dst: -1, morphs: (surface: 弱っ, base: 弱る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012FDC8>, <__main__.Morph object at 0x000001AB1012FE08>, <__main__.Morph object at 0x000001AB1012FE88>]
# -1
# srcs: 3, dst: -1, morphs: (surface: 弱っ, base: 弱る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1012FF88>, <__main__.Morph object at 0x000001AB1012FFC8>]
# 4
# srcs: 4, dst: 5, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10138088>, <__main__.Morph object at 0x000001AB101380C8>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 飲む, base: 飲む, pos: 動詞, pos1: 自立)
# [<__main__.Morph object at 0x000001AB10138188>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 煙草, base: 煙草, pos: 名詞, pos1: 一般 / surface: という, base: という, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10138248>, <__main__.Morph object at 0x000001AB10138288>]
# 4
# srcs: 4, dst: 5, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10138348>, <__main__.Morph object at 0x000001AB10138388>, <__main__.Morph object at 0x000001AB10138408>]
# 5
# srcs: 5, dst: 9, morphs: (surface: 事, base: 事, pos: 名詞, pos1: 非自立 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB10138488>, <__main__.Morph object at 0x000001AB101384C8>]
# 9
# srcs: 9, dst: -1, morphs: (surface: 知っ, base: 知る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101385C8>]
# 9
# srcs: 9, dst: -1, morphs: (surface: 知っ, base: 知る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10138688>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 頃, base: 頃, pos: 名詞, pos1: 非自立)
# [<__main__.Morph object at 0x000001AB10138748>]
# 9
# srcs: 9, dst: -1, morphs: (surface: 知っ, base: 知る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10138808>, <__main__.Morph object at 0x000001AB10138848>, <__main__.Morph object at 0x000001AB10138888>]
# -1
# srcs: 9, dst: -1, morphs: (surface: 知っ, base: 知る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10138988>]
# 1
# srcs: 1, dst: 2, morphs: (surface: 書生, base: 書生, pos: 名詞, pos1: 一般 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# [<__main__.Morph object at 0x000001AB10138A08>, <__main__.Morph object at 0x000001AB10138A48>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 掌, base: 掌, pos: 名詞, pos1: 一般 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# [<__main__.Morph object at 0x000001AB10138B08>, <__main__.Morph object at 0x000001AB10138B48>]
# 3
# srcs: 3, dst: 7, morphs: (surface: 裏, base: 裏, pos: 名詞, pos1: 一般 / surface: で, base: で, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10138C08>, <__main__.Morph object at 0x000001AB10138C48>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 坐っ, base: 坐る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10138D08>, <__main__.Morph object at 0x000001AB10138D48>]
# 5
# srcs: 5, dst: 6, morphs: (surface: よい, base: よい, pos: 形容詞, pos1: 自立)
# [<__main__.Morph object at 0x000001AB10138E08>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 心持, base: 心持, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10138F08>, <__main__.Morph object at 0x000001AB10138F48>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 坐っ, base: 坐る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10140048>, <__main__.Morph object at 0x000001AB10140088>]
# 8
# srcs: 8, dst: 13, morphs: (surface: おっ, base: おる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: が, base: が, pos: 助詞, pos1: 接続助詞 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# [<__main__.Morph object at 0x000001AB10140148>, <__main__.Morph object at 0x000001AB10140188>, <__main__.Morph object at 0x000001AB10140208>, <__main__.Morph object at 0x000001AB10140248>]
# 13
# srcs: 13, dst: -1, morphs: (surface: 運転, base: 運転, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: 始め, base: 始める, pos: 動詞, pos1: 非自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101402C8>]
# 10
# srcs: 10, dst: 13, morphs: (surface: する, base: する, pos: 動詞, pos1: 自立 / surface: と, base: と, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB101408C8>, <__main__.Morph object at 0x000001AB10140908>]
# 1
# srcs: 1, dst: 3, morphs: (surface: 動く, base: 動く, pos: 動詞, pos1: 自立 / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: か, base: か, pos: 助詞, pos1: 副助詞／並立助詞／終助詞)
# [<__main__.Morph object at 0x000001AB10140988>, <__main__.Morph object at 0x000001AB101409C8>, <__main__.Morph object at 0x000001AB10140A48>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 動く, base: 動く, pos: 動詞, pos1: 自立 / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: か, base: か, pos: 助詞, pos1: 副助詞／並立助詞／終助詞)
# [<__main__.Morph object at 0x000001AB10140AC8>, <__main__.Morph object at 0x000001AB10140B08>, <__main__.Morph object at 0x000001AB10140B88>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 動く, base: 動く, pos: 動詞, pos1: 自立 / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: か, base: か, pos: 助詞, pos1: 副助詞／並立助詞／終助詞)
# [<__main__.Morph object at 0x000001AB10140C08>, <__main__.Morph object at 0x000001AB10140C48>, <__main__.Morph object at 0x000001AB10140CC8>]
# 4
# srcs: 4, dst: 7, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: が, base: が, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10140D48>, <__main__.Morph object at 0x000001AB10140D88>, <__main__.Morph object at 0x000001AB10140E08>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 廻る, base: 廻る, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10140E88>, <__main__.Morph object at 0x000001AB10140EC8>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 廻る, base: 廻る, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10140FC8>, <__main__.Morph object at 0x000001AB10145048>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 廻る, base: 廻る, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145108>, <__main__.Morph object at 0x000001AB10145148>]
# -1
# srcs: 7, dst: -1, morphs: (surface: 廻る, base: 廻る, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145288>, <__main__.Morph object at 0x000001AB101452C8>]
# 1
# srcs: 1, dst: -1, morphs: (surface: 悪く, base: 悪い, pos: 形容詞, pos1: 自立 / surface: なる, base: なる, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145348>, <__main__.Morph object at 0x000001AB10145388>, <__main__.Morph object at 0x000001AB10145408>]
# -1
# srcs: 1, dst: -1, morphs: (surface: 悪く, base: 悪い, pos: 形容詞, pos1: 自立 / surface: なる, base: なる, pos: 動詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145508>]
# 1
# srcs: 1, dst: 2, morphs: (surface: 助から, base: 助かる, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: と, base: と, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10145588>, <__main__.Morph object at 0x000001AB101455C8>, <__main__.Morph object at 0x000001AB10145648>]
# 2
# srcs: 2, dst: 8, morphs: (surface: 思っ, base: 思う, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: と, base: と, pos: 助詞, pos1: 接続助詞 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# [<__main__.Morph object at 0x000001AB101456C8>, <__main__.Morph object at 0x000001AB10145708>, <__main__.Morph object at 0x000001AB10145788>, <__main__.Morph object at 0x000001AB101457C8>, <__main__.Morph object at 0x000001AB10145808>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 出, base: 出る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101458C8>, <__main__.Morph object at 0x000001AB10145908>, <__main__.Morph object at 0x000001AB10145988>]
# 5
# srcs: 5, dst: 8, morphs: (surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10145A08>, <__main__.Morph object at 0x000001AB10145A48>]
# 5
# srcs: 5, dst: 8, morphs: (surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10145B08>, <__main__.Morph object at 0x000001AB10145B48>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 出, base: 出る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145C48>, <__main__.Morph object at 0x000001AB10145C88>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 出, base: 出る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145D48>, <__main__.Morph object at 0x000001AB10145D88>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 出, base: 出る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145E48>, <__main__.Morph object at 0x000001AB10145E88>, <__main__.Morph object at 0x000001AB10145F08>]
# -1
# srcs: 8, dst: -1, morphs: (surface: 出, base: 出る, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10145FC8>, <__main__.Morph object at 0x000001AB1014C048>, <__main__.Morph object at 0x000001AB1014C088>]
# 1
# srcs: 1, dst: 7, morphs: (surface: 記憶, base: 記憶, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: が, base: が, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1014C108>, <__main__.Morph object at 0x000001AB1014C148>, <__main__.Morph object at 0x000001AB1014C1C8>, <__main__.Morph object at 0x000001AB1014C208>, <__main__.Morph object at 0x000001AB1014C248>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1014C308>, <__main__.Morph object at 0x000001AB1014C348>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1014C408>, <__main__.Morph object at 0x000001AB1014C448>]
# 4
# srcs: 4, dst: 7, morphs: (surface: 事, base: 事, pos: 名詞, pos1: 非自立 / surface: やら, base: やら, pos: 助詞, pos1: 終助詞)
# [<__main__.Morph object at 0x000001AB1014C508>, <__main__.Morph object at 0x000001AB1014C548>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1014C608>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 考え出そ, base: 考え出す, pos: 動詞, pos1: 自立 / surface: う, base: う, pos: 助動詞, pos1: * / surface: として, base: として, pos: 助詞, pos1: 格助詞 / surface: も, base: も, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB1014C708>, <__main__.Morph object at 0x000001AB1014C748>, <__main__.Morph object at 0x000001AB1014C7C8>, <__main__.Morph object at 0x000001AB1014C808>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1014C888>, <__main__.Morph object at 0x000001AB1014C8C8>, <__main__.Morph object at 0x000001AB1014C948>]
# -1
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1014CA48>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 付い, base: 付く, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1014CAC8>, <__main__.Morph object at 0x000001AB1014CB08>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 付い, base: 付く, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1014CBC8>, <__main__.Morph object at 0x000001AB1014CC08>]
# 3
# srcs: 3, dst: 5, morphs: (surface: 見る, base: 見る, pos: 動詞, pos1: 自立 / surface: と, base: と, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1014CCC8>, <__main__.Morph object at 0x000001AB1014CD08>]
# 5
# srcs: 5, dst: -1, morphs: (surface: い, base: いる, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1014CDC8>, <__main__.Morph object at 0x000001AB1014CE08>]
# 5
# srcs: 5, dst: -1, morphs: (surface: い, base: いる, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1014CEC8>, <__main__.Morph object at 0x000001AB1014CF08>, <__main__.Morph object at 0x000001AB1014CFC8>]
# -1
# srcs: 5, dst: -1, morphs: (surface: い, base: いる, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151108>]
# 1
# srcs: 1, dst: 2, morphs: (surface: おっ, base: おる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10151188>, <__main__.Morph object at 0x000001AB101511C8>]
# 2
# srcs: 2, dst: 4, morphs: (surface: 兄弟, base: 兄弟, pos: 名詞, pos1: 一般 / surface: が, base: が, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10151288>, <__main__.Morph object at 0x000001AB101512C8>]
# 4
# srcs: 4, dst: -1, morphs: (surface: 見え, base: 見える, pos: 動詞, pos1: 自立 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151388>, <__main__.Morph object at 0x000001AB101513C8>]
# 4
# srcs: 4, dst: -1, morphs: (surface: 見え, base: 見える, pos: 動詞, pos1: 自立 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151488>, <__main__.Morph object at 0x000001AB101514C8>, <__main__.Morph object at 0x000001AB10151548>]
# -1
# srcs: 4, dst: -1, morphs: (surface: 見え, base: 見える, pos: 動詞, pos1: 自立 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151688>, <__main__.Morph object at 0x000001AB101516C8>]
# 1
# srcs: 1, dst: 3, morphs: (surface: 母親, base: 母親, pos: 名詞, pos1: 一般 / surface: さえ, base: さえ, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB10151748>, <__main__.Morph object at 0x000001AB10151788>]
# 3
# srcs: 3, dst: -1, morphs: (surface: 隠し, base: 隠す, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: しまっ, base: しまう, pos: 動詞, pos1: 非自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151848>, <__main__.Morph object at 0x000001AB10151888>]
# 3
# srcs: 3, dst: -1, morphs: (surface: 隠し, base: 隠す, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: しまっ, base: しまう, pos: 動詞, pos1: 非自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151948>, <__main__.Morph object at 0x000001AB10151988>, <__main__.Morph object at 0x000001AB10151A08>, <__main__.Morph object at 0x000001AB10151A48>, <__main__.Morph object at 0x000001AB10151A88>]
# -1
# srcs: 3, dst: -1, morphs: (surface: 隠し, base: 隠す, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: しまっ, base: しまう, pos: 動詞, pos1: 非自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151BC8>]
# 1
# srcs: 1, dst: 2, morphs: (surface: 上今, base: 上今, pos: 名詞, pos1: 固有名詞 / surface: まで, base: まで, pos: 助詞, pos1: 副助詞 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# [<__main__.Morph object at 0x000001AB10151C48>, <__main__.Morph object at 0x000001AB10151C88>, <__main__.Morph object at 0x000001AB10151D08>]
# 2
# srcs: 2, dst: 3, morphs: (surface: 所, base: 所, pos: 名詞, pos1: 非自立 / surface: と, base: と, pos: 助詞, pos1: 格助詞 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB10151D88>, <__main__.Morph object at 0x000001AB10151DC8>, <__main__.Morph object at 0x000001AB10151E48>]
# 3
# srcs: 3, dst: 5, morphs: (surface: 違っ, base: 違う, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10151EC8>, <__main__.Morph object at 0x000001AB10151F08>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 明るい, base: 明るい, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10151FC8>, <__main__.Morph object at 0x000001AB10155048>]
# 5
# srcs: 5, dst: -1, morphs: (surface: 明るい, base: 明るい, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10155108>, <__main__.Morph object at 0x000001AB10155148>]
# -1
# srcs: 5, dst: -1, morphs: (surface: 明るい, base: 明るい, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101552C8>, <__main__.Morph object at 0x000001AB10155308>]
# 1
# srcs: 1, dst: -1, morphs: (surface: 明い, base: 明く, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: い, base: いる, pos: 動詞, pos1: 非自立 / surface: られ, base: られる, pos: 動詞, pos1: 接尾 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: くらい, base: くらい, pos: 助詞, pos1: 副助詞 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10155388>, <__main__.Morph object at 0x000001AB101553C8>, <__main__.Morph object at 0x000001AB10155448>, <__main__.Morph object at 0x000001AB10155488>, <__main__.Morph object at 0x000001AB101554C8>, <__main__.Morph object at 0x000001AB10155548>, <__main__.Morph object at 0x000001AB10155588>, <__main__.Morph object at 0x000001AB101555C8>]
# -1
# srcs: 1, dst: -1, morphs: (surface: 明い, base: 明く, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: い, base: いる, pos: 動詞, pos1: 非自立 / surface: られ, base: られる, pos: 動詞, pos1: 接尾 / surface: ぬ, base: ぬ, pos: 助動詞, pos1: * / surface: くらい, base: くらい, pos: 助詞, pos1: 副助詞 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101556C8>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 痛い, base: 痛い, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10155748>, <__main__.Morph object at 0x000001AB10155788>]
# 3
# ...
# [<__main__.Morph object at 0x000001AB1017F6C8>, <__main__.Morph object at 0x000001AB1017F708>]
# 10
# srcs: 10, dst: -1, morphs: (surface: 餓死, base: 餓死, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: かも, base: かも, pos: 助詞, pos1: 副助詞 / surface: 知れ, base: 知れる, pos: 動詞, pos1: 自立 / surface: ん, base: ん, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1017FB08>, <__main__.Morph object at 0x000001AB1017FB48>]
# 1
# srcs: 1, dst: 3, morphs: (surface: 蔭, base: 蔭, pos: 名詞, pos1: 一般 / surface: と, base: と, pos: 助詞, pos1: 格助詞 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB1017FBC8>, <__main__.Morph object at 0x000001AB1017FC08>, <__main__.Morph object at 0x000001AB1017FC88>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 云っ, base: 云う, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB1017FD08>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 云っ, base: 云う, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB1017FDC8>, <__main__.Morph object at 0x000001AB1017FE08>]
# 4
# srcs: 4, dst: -1, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1017FEC8>, <__main__.Morph object at 0x000001AB1017FF08>, <__main__.Morph object at 0x000001AB1017FF88>]
# -1
# srcs: 4, dst: -1, morphs: (surface: もの, base: もの, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10184108>]
# 1
# srcs: 1, dst: 2, morphs: (surface: 垣根, base: 垣根, pos: 名詞, pos1: 一般 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# [<__main__.Morph object at 0x000001AB10184188>, <__main__.Morph object at 0x000001AB101841C8>]
# 2
# srcs: 2, dst: 11, morphs: (surface: 穴, base: 穴, pos: 名詞, pos1: 一般 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB10184288>, <__main__.Morph object at 0x000001AB101842C8>]
# 11
# srcs: 11, dst: -1, morphs: (surface: なっ, base: なる, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: いる, base: いる, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10184388>, <__main__.Morph object at 0x000001AB101843C8>]
# 4
# srcs: 4, dst: 8, morphs: (surface: 至る, base: 至る, pos: 動詞, pos1: 自立 / surface: まで, base: まで, pos: 助詞, pos1: 副助詞)
# [<__main__.Morph object at 0x000001AB10184488>, <__main__.Morph object at 0x000001AB101844C8>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 訪問, base: 訪問, pos: 名詞, pos1: サ変接続 / surface: する, base: する, pos: 動詞, pos1: 自立)
# [<__main__.Morph object at 0x000001AB10184588>, <__main__.Morph object at 0x000001AB101845C8>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 訪問, base: 訪問, pos: 名詞, pos1: サ変接続 / surface: する, base: する, pos: 動詞, pos1: 自立)
# [<__main__.Morph object at 0x000001AB101846C8>, <__main__.Morph object at 0x000001AB10184708>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 三, base: 三, pos: 名詞, pos1: 数 / surface: 毛, base: 毛, pos: 名詞, pos1: 接尾 / surface: を, base: を, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB101847C8>, <__main__.Morph object at 0x000001AB10184808>, <__main__.Morph object at 0x000001AB10184888>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 訪問, base: 訪問, pos: 名詞, pos1: サ変接続 / surface: する, base: する, pos: 動詞, pos1: 自立)
# [<__main__.Morph object at 0x000001AB10184908>, <__main__.Morph object at 0x000001AB10184948>]
# 9
# srcs: 9, dst: 10, morphs: (surface: 時, base: 時, pos: 名詞, pos1: 非自立 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# [<__main__.Morph object at 0x000001AB10184A08>, <__main__.Morph object at 0x000001AB10184A48>]
# 10
# srcs: 10, dst: 11, morphs: (surface: 通路, base: 通路, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10184DC8>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10184E48>, <__main__.Morph object at 0x000001AB10184E88>, <__main__.Morph object at 0x000001AB10184F08>]
# 2
# srcs: 2, dst: 7, morphs: (surface: 忍び込ん, base: 忍び込む, pos: 動詞, pos1: 自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: ものの, base: ものの, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10184F88>, <__main__.Morph object at 0x000001AB10184FC8>, <__main__.Morph object at 0x000001AB10189088>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10189108>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 善い, base: 善い, pos: 形容詞, pos1: 自立 / surface: か, base: か, pos: 助詞, pos1: 副助詞／並立助詞／終助詞)
# [<__main__.Morph object at 0x000001AB101891C8>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 善い, base: 善い, pos: 形容詞, pos1: 自立 / surface: か, base: か, pos: 助詞, pos1: 副助詞／並立助詞／終助詞)
# [<__main__.Morph object at 0x000001AB10189288>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 善い, base: 善い, pos: 形容詞, pos1: 自立 / surface: か, base: か, pos: 助詞, pos1: 副助詞／並立助詞／終助詞)
# [<__main__.Morph object at 0x000001AB10189388>, <__main__.Morph object at 0x000001AB101893C8>]
# 7
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10189488>, <__main__.Morph object at 0x000001AB101894C8>, <__main__.Morph object at 0x000001AB10189548>]
# -1
# srcs: 7, dst: -1, morphs: (surface: 分ら, base: 分る, pos: 動詞, pos1: 自立 / surface: ない, base: ない, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10189648>]
# 1
# srcs: 1, dst: 2, morphs: (surface: うち, base: うち, pos: 名詞, pos1: 非自立 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB101896C8>, <__main__.Morph object at 0x000001AB10189708>]
# 2
# srcs: 2, dst: 4, morphs: (surface: 暗く, base: 暗い, pos: 形容詞, pos1: 自立 / surface: なる, base: なる, pos: 動詞, pos1: 自立 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# [<__main__.Morph object at 0x000001AB101897C8>, <__main__.Morph object at 0x000001AB10189808>, <__main__.Morph object at 0x000001AB10189888>]
# 4
# srcs: 4, dst: 6, morphs: (surface: 減る, base: 減る, pos: 動詞, pos1: 自立 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# [<__main__.Morph object at 0x000001AB10189908>, <__main__.Morph object at 0x000001AB10189948>]
# 4
# srcs: 4, dst: 6, morphs: (surface: 減る, base: 減る, pos: 動詞, pos1: 自立 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# [<__main__.Morph object at 0x000001AB10189A08>, <__main__.Morph object at 0x000001AB10189A48>]
# 6
# srcs: 6, dst: 8, morphs: (surface: 寒し, base: 寒い, pos: 形容詞, pos1: 自立 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# [<__main__.Morph object at 0x000001AB10189B08>, <__main__.Morph object at 0x000001AB10189B48>, <__main__.Morph object at 0x000001AB10189C08>]
# 6
# srcs: 6, dst: 8, morphs: (surface: 寒し, base: 寒い, pos: 形容詞, pos1: 自立 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# [<__main__.Morph object at 0x000001AB10189C88>, <__main__.Morph object at 0x000001AB10189CC8>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 降っ, base: 降る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: 来る, base: 来る, pos: 動詞, pos1: 非自立 / surface: という, base: という, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10189D88>, <__main__.Morph object at 0x000001AB10189DC8>]
# 8
# srcs: 8, dst: 9, morphs: (surface: 降っ, base: 降る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: 来る, base: 来る, pos: 動詞, pos1: 非自立 / surface: という, base: という, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10189E88>, <__main__.Morph object at 0x000001AB10189EC8>, <__main__.Morph object at 0x000001AB10189F48>, <__main__.Morph object at 0x000001AB10189F88>]
# 9
# srcs: 9, dst: 13, morphs: (surface: 始末, base: 始末, pos: 名詞, pos1: サ変接続 / surface: で, base: で, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1018E048>, <__main__.Morph object at 0x000001AB1018E088>]
# 13
# srcs: 13, dst: -1, morphs: (surface: 出来, base: 出来る, pos: 動詞, pos1: 自立 / surface: なく, base: ない, pos: 助動詞, pos1: * / surface: なっ, base: なる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1018E648>, <__main__.Morph object at 0x000001AB1018E688>]
# 1
# srcs: 1, dst: 3, morphs: (surface: ない, base: ない, pos: 形容詞, pos1: 自立 / surface: から, base: から, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1018E708>, <__main__.Morph object at 0x000001AB1018E748>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 明るく, base: 明るい, pos: 形容詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1018E808>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 明るく, base: 明るい, pos: 形容詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB1018E8C8>, <__main__.Morph object at 0x000001AB1018E908>]
# 4
# srcs: 4, dst: 5, morphs: (surface: 暖か, base: 暖かい, pos: 形容詞, pos1: 自立 / surface: そう, base: そう, pos: 名詞, pos1: 接尾 / surface: な, base: だ, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB1018E9C8>, <__main__.Morph object at 0x000001AB1018EA08>, <__main__.Morph object at 0x000001AB1018EA88>]
# 5
# srcs: 5, dst: 7, morphs: (surface: 方, base: 方, pos: 名詞, pos1: 非自立 / surface: へ, base: へ, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB1018EB08>, <__main__.Morph object at 0x000001AB1018EB48>]
# 7
# srcs: 7, dst: -1, morphs: (surface: あるい, base: あるく, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: 行く, base: 行く, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1018EC48>, <__main__.Morph object at 0x000001AB1018EC88>, <__main__.Morph object at 0x000001AB1018ED08>]
# 7
# srcs: 7, dst: -1, morphs: (surface: あるい, base: あるく, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: 行く, base: 行く, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1018ED88>, <__main__.Morph object at 0x000001AB1018EDC8>, <__main__.Morph object at 0x000001AB1018EE48>, <__main__.Morph object at 0x000001AB1018EE88>]
# -1
# srcs: 7, dst: -1, morphs: (surface: あるい, base: あるく, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: 行く, base: 行く, pos: 動詞, pos1: 非自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB1018EF88>, <__main__.Morph object at 0x000001AB1018EFC8>]
# 1
# srcs: 1, dst: 8, morphs: (surface: 考える, base: 考える, pos: 動詞, pos1: 自立 / surface: と, base: と, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10193088>, <__main__.Morph object at 0x000001AB101930C8>]
# 8
# srcs: 8, dst: -1, morphs: (surface: おっ, base: おる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10193188>]
# 3
# srcs: 3, dst: 8, morphs: (surface: 時, base: 時, pos: 名詞, pos1: 非自立 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# [<__main__.Morph object at 0x000001AB10193248>, <__main__.Morph object at 0x000001AB10193288>]
# 8
# srcs: 8, dst: -1, morphs: (surface: おっ, base: おる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10193348>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 這入っ, base: 這入る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10193408>, <__main__.Morph object at 0x000001AB10193448>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 内, base: 内, pos: 名詞, pos1: 非自立 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10193548>, <__main__.Morph object at 0x000001AB10193588>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 這入っ, base: 這入る, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞)
# [<__main__.Morph object at 0x000001AB10193648>, <__main__.Morph object at 0x000001AB10193688>]
# 8
# srcs: 8, dst: -1, morphs: (surface: おっ, base: おる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10193748>, <__main__.Morph object at 0x000001AB10193788>, <__main__.Morph object at 0x000001AB10193808>, <__main__.Morph object at 0x000001AB10193848>, <__main__.Morph object at 0x000001AB10193888>]
# -1
# srcs: 8, dst: -1, morphs: (surface: おっ, base: おる, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: だ, base: だ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10193988>, <__main__.Morph object at 0x000001AB101939C8>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 遭遇, base: 遭遇, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10193A48>, <__main__.Morph object at 0x000001AB10193A88>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 遭遇, base: 遭遇, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB10193B48>, <__main__.Morph object at 0x000001AB10193B88>]
# 3
# srcs: 3, dst: 4, morphs: (surface: 書生, base: 書生, pos: 名詞, pos1: 一般 / surface: 以外, base: 以外, pos: 名詞, pos1: 非自立 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# [<__main__.Morph object at 0x000001AB10193C48>, <__main__.Morph object at 0x000001AB10193C88>, <__main__.Morph object at 0x000001AB10193D08>]
# 4
# srcs: 4, dst: 6, morphs: (surface: 人間, base: 人間, pos: 名詞, pos1: 一般 / surface: を, base: を, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB10193D88>, <__main__.Morph object at 0x000001AB10193DC8>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 見る, base: 見る, pos: 動詞, pos1: 自立 / surface: べき, base: べし, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10193E88>]
# 6
# srcs: 6, dst: 7, morphs: (surface: 見る, base: 見る, pos: 動詞, pos1: 自立 / surface: べき, base: べし, pos: 助動詞, pos1: *)
# [<__main__.Morph object at 0x000001AB10193F88>, <__main__.Morph object at 0x000001AB10193FC8>]
# 7
# srcs: 7, dst: 8, morphs: (surface: 機会, base: 機会, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# [<__main__.Morph object at 0x000001AB101970C8>, <__main__.Morph object at 0x000001AB10197108>]
# 8
# srcs: 8, dst: -1, morphs: (surface: 遭遇, base: 遭遇, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# [<__main__.Morph object at 0x000001AB101971C8>, <__main__.Morph object at 0x000001AB10197208>, <__main__.Morph object at 0x000001AB10197288>, <__main__.Morph object at 0x000001AB101972C8>, <__main__.Morph object at 0x000001AB10197308>, <__main__.Morph object at 0x000001AB10197388>, <__main__.Morph object at 0x000001AB101973C8>]
# -1
# srcs: 8, dst: -1, morphs: (surface: 遭遇, base: 遭遇, pos: 名詞, pos1: サ変接続 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: た, base: た, pos: 助動詞, pos1: * / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: で, base: だ, pos: 助動詞, pos1: * / surface: ある, base: ある, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
